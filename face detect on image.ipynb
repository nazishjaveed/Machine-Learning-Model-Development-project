# %% [markdown]
# # Import The Library

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('male1.jpg')

# %%
img.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# # Convert The Gray Scale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap = 'gray')

# %% [markdown]
# # Make A Rectangle

# %%
haar = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces = haar.detectMultiScale(gray) # tell about the face coordinates
print(faces)
# Out:
# [[ 41  51 175 175]]

# %%
cv2.rectangle(img, (41,51), (41+175 , 51+175),(0,255,0),3)
# Out:
# array([[[160, 155, 156],
#         [160, 155, 156],
#         [162, 157, 158],
#         ...,
#         [163, 161, 160],
#         [161, 159, 158],
#         [159, 157, 157]],
#
#        [[161, 156, 157],
#         [161, 156, 157],
#         [162, 157, 158],
#         ...,
#         [164, 162, 161],
#         [163, 161, 160],
#         [161, 159, 158]],
#
#        [[163, 158, 159],
#         [163, 158, 159],
#         [163, 159, 158],
#         ...,
#         [166, 164, 163],
#         [165, 163, 162],
#         [163, 161, 160]],
#
#        ...,
#
#        [[161, 159, 159],
#         [161, 159, 159],
#         [161, 159, 159],
#         ...,
#         [ 93,  82,  78],
#         [ 84,  73,  69],
#         [ 82,  71,  67]],
#
#        [[161, 159, 159],
#         [161, 159, 159],
#         [161, 159, 159],
#         ...,
#         [100,  89,  85],
#         [ 95,  84,  80],
#         [ 86,  75,  71]],
#
#        [[158, 156, 156],
#         [158, 156, 156],
#         [158, 156, 156],
# ...

# %%
plt.imshow(img)

# %% [markdown]
# # Face Detection

# %%
cv2.imshow('detection',img)

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Face Crop

# %%
face_crop = img[50:50+261, 60:60+261]

# %%
plt.imshow(face_crop)

# %%
cv2.imwrite('male_02.png', face_crop)
# Out:
# True
